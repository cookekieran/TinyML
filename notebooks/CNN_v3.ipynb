# %%
import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

import time
import matplotlib.pyplot as plt
import numpy as np

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((96, 96)),
    transforms.RandomHorizontalFlip(0.5), # data augmentation
    transforms.RandomRotation(10),      
    transforms.ToTensor(),
])

transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((96, 96)),
    transforms.ToTensor(),
])

train_dataset = datasets.ImageFolder(root='data/training/', transform=train_transform)
val_dataset = datasets.ImageFolder(root='data/training/', transform=transform)

print(f"Total training images: {len(train_dataset)}")
print(f"Classes found: {train_dataset.classes}")

train_size = int(0.7 * len(train_dataset))
val_size = int(0.15 * len(train_dataset))
test_size = len(train_dataset) - train_size - val_size

indices = list(range(len(train_dataset)))
np.random.seed(0)
np.random.shuffle(indices)

train_idx = indices[:train_size]
val_idx = indices[train_size : train_size + val_size]
test_idx = indices[train_size + val_size :]

train_data = torch.utils.data.Subset(train_dataset, train_idx)
val_data = torch.utils.data.Subset(val_dataset, val_idx)
test_data = torch.utils.data.Subset(val_dataset, test_idx)

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32, shuffle=False)
test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

print(f"Train: {len(train_data)} | Val: {len(val_data)} | Test: {len(test_data)}")
# Out:
# Total training images: 895
# Classes found: ['hand', 'no_hand']
# Train: 626 | Val: 134 | Test: 135

# %%
class TinyCNN(torch.nn.Module):
    def __init__(self, num_outputs):
        super(TinyCNN, self).__init__()
        
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=2, padding=1)
        self.rl1 = nn.ReLU()
        
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=1)
        self.rl2 = nn.ReLU()

        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1)
        self.rl3 = nn.ReLU()

        self.pool = nn.AdaptiveAvgPool2d(1)
        self.flatten = nn.Flatten()
        
        self.linear1 = nn.Linear(64, 32)
        self.rl4 = nn.ReLU()
        self.dropout1 = nn.Dropout(0.4)
        self.linear2 = nn.Linear(32, num_outputs)

    def forward(self, x):
        x = self.rl1(self.conv1(x))
        x = self.rl2(self.conv2(x))
        x = self.rl3(self.conv3(x))
        x = self.pool(x)
        x = self.flatten(x)
        x = self.rl4(self.linear1(x))
        x = self.dropout1(x)
        x = self.linear2(x)
        return x

# %%
def init_weights(m):
    if type(m) == torch.nn.Linear or type(m) == torch.nn.Conv2d:
        torch.nn.init.xavier_uniform_(m.weight)
        
num_classes = 2
model = TinyCNN(num_outputs=num_classes).to(device)
model.apply(init_weights)
# Out:
# TinyCNN(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (rl1): ReLU()
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (rl2): ReLU()
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#   (rl3): ReLU()
#   (pool): AdaptiveAvgPool2d(output_size=1)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear1): Linear(in_features=64, out_features=32, bias=True)
#   (rl4): ReLU()
#   (dropout1): Dropout(p=0.4, inplace=False)
#   (linear2): Linear(in_features=32, out_features=2, bias=True)
# )

# %%
def correct(logits, y):
    y_hat = logits.argmax(axis=1)
    return (y_hat == y).float().sum()
    
def evaluate_metric(model, data_iter, metric):
    c = 0.
    n = 0.
    model.eval()
    with torch.no_grad():
        for X, y in data_iter:
            X, y = X.to(device), y.to(device)
            logits = model(X)
            c += metric(logits, y)
            n += len(y)
    return float(c / n)

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
num_epochs = 1000

losses = []
train_accs = []
test_accs = []


best_val_acc = 0.0
patience = 25    
counter = 0    
best_model_path = 'best_model5.pth'


for epoch in range(num_epochs):
    model.train()
    start_time = time.perf_counter()
    train_loss = 0.0
    train_correct_count = 0
    train_total = 0
    
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        
        outputs = model(images)
        loss_val = criterion(outputs, labels)
        
        
        optimizer.zero_grad()
        loss_val.backward()
        optimizer.step()
        
        
        losses.append(loss_val.item())
        train_loss += loss_val.item()
        _, predicted = torch.max(outputs.data, 1)
        train_total += labels.size(0)
        train_correct_count += (predicted == labels).sum().item()

    
    model.eval() 
    with torch.no_grad():
        val_acc_raw = evaluate_metric(model, val_loader, correct)
        val_acc = val_acc_raw * 100
    
    train_acc = 100 * train_correct_count / train_total
    train_accs.append(train_acc / 100)
    test_accs.append(val_acc_raw)
    
    end_time = time.perf_counter()
    print(f"Epoch [{epoch+1}/{num_epochs}]")
    print(f"Train Loss: {train_loss/len(train_loader):.4f} | Train Acc: {train_acc:.2f}%")
    print(f"Val Acc: {val_acc:.2f}% | Duration: {end_time - start_time:.3f}s")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        counter = 0
        torch.save(model.state_dict(), best_model_path)
        print(f"--> Best model saved (Val Acc: {val_acc:.2f}%)")
    else:
        counter += 1
        print(f"No improvement for {counter} epoch(s).")
    
    if counter >= patience:
        print(f"\nEarly stopping triggered! Training stopped at epoch {epoch+1}")
        break
    print("-" * 30)

model.load_state_dict(torch.load(best_model_path))
print(f"\nLoaded best model with Validation Accuracy: {best_val_acc:.2f}%")

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(losses)
plt.xlabel('Training batch')
plt.ylabel('Cross entropy loss')

plt.subplot(1, 2, 2)
plt.plot(train_accs, label='Training accuracy')
plt.plot(test_accs, label='Validation accuracy')
plt.xlabel('Epoch')
plt.legend(loc='best')
plt.show()
# Out:
# Epoch [1/1000]
# Train Loss: 0.6829 | Train Acc: 52.56%
# Val Acc: 49.25% | Duration: 11.035s
# --> Best model saved (Val Acc: 49.25%)
# ------------------------------
# Epoch [2/1000]
# Train Loss: 0.6241 | Train Acc: 60.38%
# Val Acc: 72.39% | Duration: 9.114s
# --> Best model saved (Val Acc: 72.39%)
# ------------------------------
# Epoch [3/1000]
# Train Loss: 0.5316 | Train Acc: 70.45%
# Val Acc: 67.91% | Duration: 6.957s
# No improvement for 1 epoch(s).
# ------------------------------
# Epoch [4/1000]
# Train Loss: 0.5003 | Train Acc: 73.00%
# Val Acc: 71.64% | Duration: 6.395s
# No improvement for 2 epoch(s).
# ------------------------------
# Epoch [5/1000]
# Train Loss: 0.4597 | Train Acc: 72.68%
# Val Acc: 72.39% | Duration: 6.442s
# No improvement for 3 epoch(s).
# ------------------------------
# Epoch [6/1000]
# Train Loss: 0.4592 | Train Acc: 72.52%
# Val Acc: 64.18% | Duration: 6.426s
# No improvement for 4 epoch(s).
# ------------------------------
# Epoch [7/1000]
# Train Loss: 0.4460 | Train Acc: 73.32%
# Val Acc: 61.94% | Duration: 7.467s
# No improvement for 5 epoch(s).
# ------------------------------
# Epoch [8/1000]
# Train Loss: 0.4245 | Train Acc: 74.92%
# Val Acc: 67.91% | Duration: 6.876s
# No improvement for 6 epoch(s).
# ------------------------------
# Epoch [9/1000]
# Train Loss: 0.4198 | Train Acc: 74.12%
# Val Acc: 67.16% | Duration: 6.670s
# No improvement for 7 epoch(s).
# ------------------------------
# Epoch [10/1000]
# Train Loss: 0.4118 | Train Acc: 76.84%
# Val Acc: 71.64% | Duration: 6.361s
# No improvement for 8 epoch(s).
# ------------------------------
# Epoch [11/1000]
# Train Loss: 0.4185 | Train Acc: 74.60%
# Val Acc: 70.15% | Duration: 6.500s
# No improvement for 9 epoch(s).
# ------------------------------
# Epoch [12/1000]
# Train Loss: 0.4182 | Train Acc: 74.12%
# Val Acc: 65.67% | Duration: 9.875s
# No improvement for 10 epoch(s).
# ------------------------------
# Epoch [13/1000]
# Train Loss: 0.3956 | Train Acc: 77.96%
# Val Acc: 69.40% | Duration: 10.918s
# No improvement for 11 epoch(s).
# ------------------------------
# Epoch [14/1000]
# Train Loss: 0.3954 | Train Acc: 78.27%
# Val Acc: 64.93% | Duration: 10.087s
# No improvement for 12 epoch(s).
# ------------------------------
# Epoch [15/1000]
# Train Loss: 0.3818 | Train Acc: 76.20%
# Val Acc: 64.93% | Duration: 10.104s
# No improvement for 13 epoch(s).
# ------------------------------
# Epoch [16/1000]
# Train Loss: 0.3855 | Train Acc: 77.80%
# Val Acc: 70.90% | Duration: 9.503s
# No improvement for 14 epoch(s).
# ------------------------------
# Epoch [17/1000]
# Train Loss: 0.3991 | Train Acc: 76.36%
# Val Acc: 73.13% | Duration: 11.014s
# --> Best model saved (Val Acc: 73.13%)
# ------------------------------
# Epoch [18/1000]
# Train Loss: 0.3597 | Train Acc: 78.27%
# Val Acc: 73.88% | Duration: 8.446s
# --> Best model saved (Val Acc: 73.88%)
# ------------------------------
# Epoch [19/1000]
# Train Loss: 0.3738 | Train Acc: 76.20%
# Val Acc: 73.88% | Duration: 7.663s
# No improvement for 1 epoch(s).
# ------------------------------
# Epoch [20/1000]
# Train Loss: 0.3594 | Train Acc: 78.12%
# Val Acc: 66.42% | Duration: 7.867s
# No improvement for 2 epoch(s).
# ------------------------------
# Epoch [21/1000]
# Train Loss: 0.3820 | Train Acc: 76.20%
# Val Acc: 73.88% | Duration: 9.217s
# No improvement for 3 epoch(s).
# ------------------------------
# Epoch [22/1000]
# Train Loss: 0.3729 | Train Acc: 78.43%
# Val Acc: 70.90% | Duration: 8.007s
# No improvement for 4 epoch(s).
# ------------------------------
# Epoch [23/1000]
# Train Loss: 0.3446 | Train Acc: 79.23%
# Val Acc: 72.39% | Duration: 8.135s
# No improvement for 5 epoch(s).
# ------------------------------
# Epoch [24/1000]
# Train Loss: 0.3313 | Train Acc: 79.87%
# Val Acc: 73.88% | Duration: 8.855s
# No improvement for 6 epoch(s).
# ------------------------------
# Epoch [25/1000]
# Train Loss: 0.3558 | Train Acc: 79.23%
# Val Acc: 73.88% | Duration: 8.801s
# No improvement for 7 epoch(s).
# ------------------------------
# Epoch [26/1000]
# Train Loss: 0.3329 | Train Acc: 83.87%
# Val Acc: 74.63% | Duration: 9.685s
# --> Best model saved (Val Acc: 74.63%)
# ------------------------------
# Epoch [27/1000]
# Train Loss: 0.3361 | Train Acc: 80.83%
# Val Acc: 75.37% | Duration: 7.481s
# --> Best model saved (Val Acc: 75.37%)
# ------------------------------
# Epoch [28/1000]
# Train Loss: 0.3167 | Train Acc: 82.43%
# Val Acc: 84.33% | Duration: 8.631s
# --> Best model saved (Val Acc: 84.33%)
# ------------------------------
# Epoch [29/1000]
# Train Loss: 0.3171 | Train Acc: 82.11%
# Val Acc: 74.63% | Duration: 8.283s
# No improvement for 1 epoch(s).
# ------------------------------
# Epoch [30/1000]
# Train Loss: 0.3137 | Train Acc: 84.03%
# Val Acc: 89.55% | Duration: 8.504s
# --> Best model saved (Val Acc: 89.55%)
# ------------------------------
# Epoch [31/1000]
# Train Loss: 0.3165 | Train Acc: 84.19%
# Val Acc: 89.55% | Duration: 8.439s
# No improvement for 1 epoch(s).
# ------------------------------
# Epoch [32/1000]
# Train Loss: 0.2871 | Train Acc: 85.46%
# Val Acc: 90.30% | Duration: 8.521s
# --> Best model saved (Val Acc: 90.30%)
# ------------------------------
# Epoch [33/1000]
# Train Loss: 0.2994 | Train Acc: 87.54%
# Val Acc: 90.30% | Duration: 8.065s
# No improvement for 1 epoch(s).
# ------------------------------
# Epoch [34/1000]
# Train Loss: 0.2717 | Train Acc: 87.70%
# Val Acc: 94.78% | Duration: 11.466s
# --> Best model saved (Val Acc: 94.78%)
# ------------------------------
# Epoch [35/1000]
# Train Loss: 0.2776 | Train Acc: 88.66%
# Val Acc: 88.81% | Duration: 13.757s
# No improvement for 1 epoch(s).
# ------------------------------
# Epoch [36/1000]
# Train Loss: 0.2749 | Train Acc: 86.10%
# Val Acc: 87.31% | Duration: 17.217s
# No improvement for 2 epoch(s).
# ------------------------------
# Epoch [37/1000]
# Train Loss: 0.2519 | Train Acc: 90.42%
# Val Acc: 76.12% | Duration: 11.983s
# No improvement for 3 epoch(s).
# ------------------------------
# Epoch [38/1000]
# Train Loss: 0.2723 | Train Acc: 87.22%
# Val Acc: 76.12% | Duration: 14.693s
# No improvement for 4 epoch(s).
# ------------------------------
# Epoch [39/1000]
# Train Loss: 0.2789 | Train Acc: 87.38%
# Val Acc: 83.58% | Duration: 7.865s
# No improvement for 5 epoch(s).
# ------------------------------
# Epoch [40/1000]
# Train Loss: 0.2630 | Train Acc: 88.02%
# Val Acc: 91.79% | Duration: 8.383s
# No improvement for 6 epoch(s).
# ------------------------------
# Epoch [41/1000]
# Train Loss: 0.2742 | Train Acc: 88.02%
# Val Acc: 91.04% | Duration: 10.687s
# No improvement for 7 epoch(s).
# ------------------------------
# Epoch [42/1000]
# Train Loss: 0.2447 | Train Acc: 89.14%
# Val Acc: 92.54% | Duration: 13.429s
# No improvement for 8 epoch(s).
# ------------------------------
# Epoch [43/1000]
# Train Loss: 0.2466 | Train Acc: 89.30%
# Val Acc: 92.54% | Duration: 12.693s
# No improvement for 9 epoch(s).
# ------------------------------
# Epoch [44/1000]
# Train Loss: 0.2349 | Train Acc: 90.10%
# Val Acc: 97.76% | Duration: 12.866s
# --> Best model saved (Val Acc: 97.76%)
# ------------------------------
# Epoch [45/1000]
# Train Loss: 0.2460 | Train Acc: 89.62%
# Val Acc: 97.01% | Duration: 9.489s
# No improvement for 1 epoch(s).
# ------------------------------
# Epoch [46/1000]
# Train Loss: 0.2304 | Train Acc: 91.21%
# Val Acc: 96.27% | Duration: 9.627s
# No improvement for 2 epoch(s).
# ------------------------------
# Epoch [47/1000]
# Train Loss: 0.2192 | Train Acc: 91.69%
# Val Acc: 97.01% | Duration: 8.530s
# No improvement for 3 epoch(s).
# ------------------------------
# Epoch [48/1000]
# Train Loss: 0.2079 | Train Acc: 91.53%
# Val Acc: 94.78% | Duration: 8.097s
# No improvement for 4 epoch(s).
# ------------------------------
# Epoch [49/1000]
# Train Loss: 0.1954 | Train Acc: 92.97%
# Val Acc: 97.01% | Duration: 7.986s
# No improvement for 5 epoch(s).
# ------------------------------
# Epoch [50/1000]
# Train Loss: 0.2103 | Train Acc: 91.69%
# Val Acc: 91.79% | Duration: 7.935s
# No improvement for 6 epoch(s).
# ------------------------------
# Epoch [51/1000]
# Train Loss: 0.2189 | Train Acc: 91.05%
# Val Acc: 95.52% | Duration: 7.648s
# No improvement for 7 epoch(s).
# ------------------------------
# Epoch [52/1000]
# Train Loss: 0.1645 | Train Acc: 93.77%
# Val Acc: 97.01% | Duration: 8.894s
# No improvement for 8 epoch(s).
# ------------------------------
# Epoch [53/1000]
# Train Loss: 0.1788 | Train Acc: 94.09%
# Val Acc: 97.01% | Duration: 7.665s
# No improvement for 9 epoch(s).
# ------------------------------
# Epoch [54/1000]
# Train Loss: 0.1536 | Train Acc: 94.89%
# Val Acc: 95.52% | Duration: 8.744s
# No improvement for 10 epoch(s).
# ------------------------------
# Epoch [55/1000]
# Train Loss: 0.1687 | Train Acc: 95.37%
# Val Acc: 94.03% | Duration: 8.698s
# No improvement for 11 epoch(s).
# ------------------------------
# Epoch [56/1000]
# Train Loss: 0.3046 | Train Acc: 87.22%
# Val Acc: 91.04% | Duration: 9.098s
# No improvement for 12 epoch(s).
# ------------------------------
# Epoch [57/1000]
# Train Loss: 0.2412 | Train Acc: 91.21%
# Val Acc: 85.82% | Duration: 9.591s
# No improvement for 13 epoch(s).
# ------------------------------
# Epoch [58/1000]
# Train Loss: 0.2073 | Train Acc: 92.81%
# Val Acc: 97.01% | Duration: 9.000s
# No improvement for 14 epoch(s).
# ------------------------------
# Epoch [59/1000]
# Train Loss: 0.1729 | Train Acc: 93.93%
# Val Acc: 97.76% | Duration: 9.049s
# No improvement for 15 epoch(s).
# ------------------------------
# Epoch [60/1000]
# Train Loss: 0.1660 | Train Acc: 94.41%
# Val Acc: 97.01% | Duration: 8.955s
# No improvement for 16 epoch(s).
# ------------------------------
# Epoch [61/1000]
# Train Loss: 0.1523 | Train Acc: 95.21%
# Val Acc: 97.01% | Duration: 8.565s
# No improvement for 17 epoch(s).
# ------------------------------
# Epoch [62/1000]
# Train Loss: 0.1677 | Train Acc: 94.41%
# Val Acc: 94.03% | Duration: 8.710s
# No improvement for 18 epoch(s).
# ------------------------------
# Epoch [63/1000]
# Train Loss: 0.1657 | Train Acc: 94.57%
# Val Acc: 97.76% | Duration: 8.308s
# No improvement for 19 epoch(s).
# ------------------------------
# Epoch [64/1000]
# Train Loss: 0.2055 | Train Acc: 93.93%
# Val Acc: 97.01% | Duration: 8.376s
# No improvement for 20 epoch(s).
# ------------------------------
# Epoch [65/1000]
# Train Loss: 0.1560 | Train Acc: 96.33%
# Val Acc: 97.76% | Duration: 8.451s
# No improvement for 21 epoch(s).
# ------------------------------
# Epoch [66/1000]
# Train Loss: 0.1343 | Train Acc: 94.73%
# Val Acc: 97.01% | Duration: 9.330s
# No improvement for 22 epoch(s).
# ------------------------------
# Epoch [67/1000]
# Train Loss: 0.1492 | Train Acc: 94.73%
# Val Acc: 97.01% | Duration: 8.461s
# No improvement for 23 epoch(s).
# ------------------------------
# Epoch [68/1000]
# Train Loss: 0.1392 | Train Acc: 95.69%
# Val Acc: 97.01% | Duration: 9.423s
# No improvement for 24 epoch(s).
# ------------------------------
# Epoch [69/1000]
# Train Loss: 0.1567 | Train Acc: 94.89%
# Val Acc: 97.01% | Duration: 8.269s
# No improvement for 25 epoch(s).
#
# Early stopping triggered! Training stopped at epoch 69
#
# Loaded best model with Validation Accuracy: 97.76%
# C:\Users\kiera\AppData\Local\Temp\ipykernel_23864\3288779865.py:71: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_path))

# %%
model.eval()

with torch.no_grad():
    test_acc = evaluate_metric(model, test_loader, correct)

print(f"Final Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# Final Test Accuracy: 99.26%
